# %% [markdown]
# ## tensorflow 환경설치
# - pip install tensorflow==2.3.1
# - pip install keras==2.3.0
# - python -m pip install --upgrade pip

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
Data_set = np.loadtxt("../data/ThoraricSurgery3.csv", delimiter=",")  # 수술 환자 데이터를 불러옵니다.
X = Data_set[:,0:16]                                                 # 환자의 진찰 기록을 X로 지정합니다.
y = Data_set[:,16]                                                   # 수술 후 사망/생존 여부를 y로 지정합니다.

# %%
Data_set.shape # 470x17
# Out:
# (470, 16)

# %%
model = Sequential()                                                  # 딥러닝 모델의 구조를 결정합니다.
model.add(Dense(30, input_dim=16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])  # 딥러닝 모델을 실행합니다.
history=model.fit(X, y, epochs=5, batch_size=16)
# Out:
# Train on 470 samples
# Epoch 1/5
# 470/470 [==============================] - 0s 1ms/sample - loss: 2.2991 - accuracy: 0.8511
# Epoch 2/5
# 470/470 [==============================] - 0s 59us/sample - loss: 0.5881 - accuracy: 0.8255
# Epoch 3/5
# 470/470 [==============================] - 0s 57us/sample - loss: 0.4916 - accuracy: 0.8383
# Epoch 4/5
# 470/470 [==============================] - 0s 61us/sample - loss: 0.4707 - accuracy: 0.8362
# Epoch 5/5
# 470/470 [==============================] - 0s 64us/sample - loss: 0.4757 - accuracy: 0.8447

# %%
model = Sequential()                                                  # 딥러닝 모델의 구조를 결정합니다.
model.add(Dense(30, input_dim=16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])  # 딥러닝 모델을 실행합니다.
history=model.fit(X, y, epochs=5, batch_size=16)
# Out:
# Train on 470 samples
# Epoch 1/5
# 470/470 [==============================] - 0s 724us/sample - loss: 7.3175 - accuracy: 0.1532
# Epoch 2/5
# 470/470 [==============================] - 0s 58us/sample - loss: 0.5874 - accuracy: 0.7936
# Epoch 3/5
# 470/470 [==============================] - 0s 62us/sample - loss: 0.4704 - accuracy: 0.8511
# Epoch 4/5
# 470/470 [==============================] - 0s 69us/sample - loss: 0.4406 - accuracy: 0.8511
# Epoch 5/5
# 470/470 [==============================] - 0s 64us/sample - loss: 0.4345 - accuracy: 0.8511

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
